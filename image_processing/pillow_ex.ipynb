# %% [markdown]
# open cmd prompt and then write this command
# ```shell
# pip install pillow
# ```

# %%
# PIL => python image library

from PIL import Image

# %%
im = Image.open("D:/Users/HP 346 G3/OneDrive/Pictures/twitter.png")
im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=512x512 at 0x27EECDD24C0>

# %%
im2 = Image.open('D:/Users/HP 346 G3/OneDrive/Pictures/sky.jpg')
im2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=612x408 at 0x27EECAA7D00>

# %% [markdown]
# - properties
# - resize
# - rotate
# - merge
# - crop
# - writing text

# %%
im.size
# Out:
# (512, 512)

# %%
w,h = im.size
print(f"the image width is {w} and the height is {h}")
# Out:
# the image width is 512 and the height is 512

# %%
im2.size
# Out:
# (612, 408)

# %%
print(im2.format)
print(im2.mode)
print(im2.info)
# Out:
# JPEG
# RGB
# {'jfif': 257, 'jfif_version': (1, 1), 'dpi': (300, 300), 'jfif_unit': 1, 'jfif_density': (300, 300), 'exif': b'Exif\x00\x00II*\x00\x08\x00\x00\x00\x01\x00\x0e\x01\x02\x00$\x00\x00\x00\x1a\x00\x00\x00\x00\x00\x00\x00Blue sky and white clouds background', 'photoshop': {1028: b'\x1c\x02P\x00\x0bBoonyachoat\x1c\x02x\x00$Blue sky and white clouds background\x1c\x02n\x00\x18Getty Images/iStockphoto'}, 'progressive': 1, 'progression': 1}

# %%
im.resize((300,200)) # size should be in tuple
# Out:
# <PIL.Image.Image image mode=RGBA size=300x200 at 0x27EECB29160>

# %%
w,h = im.size
half_im = im.resize((w//2, h//2))
half_im.show()
im.show()

# %%
w,h = im.size
twice_im = im.resize((w*2, h*2))
twice_im
# Out:
# <PIL.Image.Image image mode=RGBA size=1024x1024 at 0x27EECB29B50>

# %%
im.rotate(90)
# Out:
# <PIL.Image.Image image mode=RGBA size=512x512 at 0x27EECAA7B80>

# %%
im2.rotate(45,fillcolor='#899f8f')
# Out:
# <PIL.Image.Image image mode=RGB size=612x408 at 0x27EECCCF4C0>

# %% [markdown]
# simple image fusion
# - image should of same size
# - image should have same mode

# %%
im3 = Image.open('D:/Users/HP 346 G3/OneDrive/Pictures/025.png')
im3
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=475x475 at 0x27EECCCF820>

# %%
im.size , im2.size, im.mode, im2.mode
# Out:
# ((512, 512), (612, 408), 'RGBA', 'RGB')

# %%
im2 = im2.convert('RGBA')

# %%
im = im.resize(im2.size)

# %%
Image.blend(im,im2,0.5)
# Out:
# <PIL.Image.Image image mode=RGBA size=612x408 at 0x27EECB29AC0>

# %%
Image.composite(im2,im,im)
# Out:
# <PIL.Image.Image image mode=RGBA size=612x408 at 0x27EECCCFAF0>

# %% [markdown]
# cropping the image

# %%
im3.crop((10,10,250,250)) # tuple with four point aka BOX
# Out:
# <PIL.Image.Image image mode=RGBA size=240x240 at 0x27EECCCF850>

# %%
from PIL import ImageDraw, ImageFont

# %%
dim3 = ImageDraw.Draw(im3)
font = ImageFont.truetype('font2.ttf', size=50)

# %%
w,h = im3.size
dim3.text((w//2,h//2),'Pikachu',fill='#3f9302',font=font,anchor='mm')
dim3.text((300,400),'Pokemon',fill='#3289ff',font=font,anchor='mm')
im3
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=475x475 at 0x27EECCCF820>
