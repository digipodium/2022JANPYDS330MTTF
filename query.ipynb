# %%
import pandas as pd

# %%
pd.read_excel('C:/Users/Admin/Downloads/netflix_titles.xlsx', sheet_name='netflix_titles')
# Out:
#      duration_minutes duration_seasons     type  \
# 0                  90              NaN    Movie
# 1                  94              NaN    Movie
# 2                 NaN                1  TV Show
# 3                 NaN                1  TV Show
# 4                  99              NaN    Movie
# ...               ...              ...      ...
# 6231              NaN               13  TV Show
# 6232              NaN                4  TV Show
# 6233               60              NaN    Movie
# 6234              NaN                2  TV Show
# 6235              NaN               10  TV Show
#
#                                             title           date_added  \
# 0         Norm of the North: King Sized Adventure  2019-09-09 00:00:00
# 1                      Jandino: Whatever it Takes  2016-09-09 00:00:00
# 2                              Transformers Prime  2018-09-08 00:00:00
# 3                Transformers: Robots in Disguise  2018-09-08 00:00:00
# ...
