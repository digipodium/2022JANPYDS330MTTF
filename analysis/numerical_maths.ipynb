# %% [markdown]
# ## we need to install numpy library
# ```
# pip install numpy matplotlib
# ```

# %%
import numpy as np

# %%
x = np.arange(15)
x

# %%
x = np.arange(15).reshape(3,5)
x

# %%
x.shape

# %%
x.ndim

# %%
x = np.arange(30).reshape(3,5,2)
x.ndim

# %%
print(x)

# %%
a = [1,2,3,3,5]
na = np.array(a)
na

# %%
b = np.array([(1,2, 3.4), (2,2,3)])
b

# %%
b.dtype

# %%
b = np.array([(1,2, 3.4), (2,2,3)], dtype='int')
b

# %%
b = np.array([(1,2, 3.4), (2,2,3)], dtype='complex')
b

# %% [markdown]
# - ### visualization libraries
#
# ```
# pip install plotly bokeh
# ```

# %% [markdown]
# # slicing in numpy

# %%
import numpy as np

# %%
x= np.random.randint(1,10, (5,5))
print(x)

# %% [markdown]
# selecting a row

# %%
x[0] # x[0,:]

# %% [markdown]
# single value (item)

# %%
x[0][3]

# %% [markdown]
# single value (item) coordinate style

# %%
x[0,3]

# %%
x[:,0]

# %%
x[:, -1] # last column

# %%
x[1:,:-1]

# %%
x = np.random.randint(1,20,(2,2))
y = np.random.randint(2,100,(3,2))
print(x)
print(y)
# Out:
# [[ 6  6]
#  [ 9 14]]
# [[56 23]
#  [83 63]
#  [19 17]]

# %%
np.vstack((x,y))

# %%
yt = y.transpose()
yt.shape

# %%
np.hstack((x,yt))

# %%
x = np.arange(-10,10,.02)
y = np.sinc(x)
z = np.cos(x)

# %%
import plotly.express as px
import matplotlib.pyplot as plt

# %%
fig = px.scatter_3d(x=x,y=y,z=z,height=500,width=500,color=z,)
fig.show() 
# fig.write_html('graph1.html',auto_open=True) # if any error happens

# %%
plt.plot(x,y,'ro--')
